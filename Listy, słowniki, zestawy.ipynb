# %%
fruits = ["jabłko", "banan", "malina"]
person = {"name": "Ala", "age": 22}
numbers = {1, 2, 3, 3}

fruits.append("gruszka")
print("Lista po dodaniu nowego elementu:", fruits)

second_fruit = fruits[1]
print("Druga wartość w liście:", second_fruit)

my_list = [4, 8, 15, 16, 23, 42]
average = sum(my_list) / len(my_list)
print("Średnia z listy:", average)

print("Dane ze słownika:")
for key, value in person.items():
    print(f"{key}: {value}")
# Out:
# Lista po dodaniu nowego elementu: ['jabłko', 'banan', 'malina', 'gruszka']
# Druga wartość w liście: banan
# Średnia z listy: 18.0
# Dane ze słownika:
# name: Ala
# age: 22
