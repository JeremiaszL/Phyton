# %%
import numpy as np
import pandas as pd


a = np.array([3, 8, 5])
b = np.array([1, 5, 2])

print("Suma wektorów a + b:")
print(a + b)

print("\nIloczyn skalarny wektorów a i b:")
print(np.dot(a, b))
# Out:
# Suma wektorów a + b:
# [ 4 13  7]
#
# Iloczyn skalarny wektorów a i b:
# 53
