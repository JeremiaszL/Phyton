# %%
a = 10
b = 3.5
c = "Python"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))

print("Dodawanie:", a + b)
print("Dzielenie:", a / b)
print("Potęgowanie:", a ** 2)

print(f"Wartość a to {a}, a b to {b}")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# Dodawanie: 13.5
# Dzielenie: 2.857142857142857
# Potęgowanie: 100
# Wartość a to 10, a b to 3.5
